# %%
import pandas as pd

df = pd.read_csv("sample.csv")
print(df)
pd.tail()
# Out:
#     barangay_id barangay_name  district  population_2020 classification  \
# 0             1        Carmen         1            77756          Urban
# 1             2      Balulang         1            42205          Urban
# 2             3     Kauswagan         1            39378          Urban
# 3             4       Lapasan         2            38680          Urban
# 4             5         Bulua         1            35167          Urban
# 5             6    Camaman-an         2            28345          Urban
# 6             7      Canitoan         1            25432          Urban
# 7             8        Lumbia         1            24890          Rural
# 8             9          Bugo         2            23560          Urban
# 9            10          Gusa         2            22190          Urban
# 10           11        Iponan         1            21890          Urban
# 11           12        Tablon         2            20560          Urban
# ...
